# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1 ="Hello"
str2 ="World"
result = str1+str2
print("Concatenated string:",result)
# Out:
# Concatenated string: HelloWorld
