# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#creating a tuple
t1=(1,2,3,4)

#finding length
print("Length of tuple:",len(t1))

#concutenation
t2=(5,6)
t3=t1+t2
print("After concutenation:",t3)

#Repetition
print("After repetion:",t1*2)

#Membership
print ("Is 3 present in tuple ?", 3 in t1)
# Out:
# Length of tuple: 4
# After concutenation: (1, 2, 3, 4, 5, 6)
# After repetion: (1, 2, 3, 4, 1, 2, 3, 4)
# Is 3 present in tuple ? True
