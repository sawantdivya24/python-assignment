# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=[1,2]
list2=[3,4]
print(list1+list2)#concatenation
print(list1*2)#repetition
print(len(list1))#length
print(max(list1))#maximum
print(min(list1))#minimum
# Out:
# [1, 2, 3, 4]
# [1, 2, 1, 2]
# 2
# 2
# 1
