# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
b=2.5
c=int(a)
d=float(a)
e=str(a)
f=bool(a)

print(type(c))
print(type(a))
print(type(e))
print(type(f))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
