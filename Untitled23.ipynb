# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#creating a tuple
t=(5,2,9,1,7)
#using built-in function
print("length:",len(t))
print("Maximum value:",max(t))
print("Minimum value:",min(t))

#using tuple () function
t1=[1,2,3]
t2=tuple(t1)
print("converted tuple:",t2)
# Out:
# length: 5
# Maximum value: 9
# Minimum value: 1
# converted tuple: (1, 2, 3)
