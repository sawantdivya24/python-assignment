# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=[1,2,3]
list1[1]=10 #update
list1.append(4)#append
list1.insert(1,20)#insert
list1.remove(3)#delete
print(list1)
# Out:
# [1, 20, 10, 4]
