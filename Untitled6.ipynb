# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("Enter a number:"))
if a%2==0:
  print("Given number is even")
else:
    print("Given number is odd")
# Out:
# Enter a number:24
# Given number is even
