# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# creating a tuple
t=(1,2,3)
#Trying to modify (will give error if uncommented)
#t[0]=10
print("Tuples are immutable cannot be changed")
#Deleting tuple
print("Tuple deleted succesfully")
# Out:
# Tuples are immutable cannot be changed
# Tuple deleted succesfully
