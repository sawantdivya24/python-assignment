# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
string=input("Enter a string:")
i=0
result=""
while i<len(string):
  if i %2==0:
    result+=string[i]
  i+=1
  print("Result:",result)
