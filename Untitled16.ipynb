# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list1=[10,20,30,40]
print(20.in list1)
print(50 not in list1)
# Out:
# True
# True
# <>:2: SyntaxWarning: invalid decimal literal
# <>:2: SyntaxWarning: invalid decimal literal
# /tmp/ipykernel_1095/2901660362.py:2: SyntaxWarning: invalid decimal literal
#   print(20.in list1)
