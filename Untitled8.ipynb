# %% [markdown]
# <a href="https://colab.research.google.com/github/sawantdivya24/python-assignment/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=input("Enter something:")

if x.isdigit():
  print("It is a number")
else:
  print("It is a character")
# Out:
# Enter something:Divya
# It is a character
